# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
import torch
import torch.utils.data as data
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as dsets
from kLSTM import *
from sklearn.metrics import accuracy_score, roc_auc_score

def train(model, device, train_loader, optimizer, config, epoch):
    model.train()   # set model in training mode
    losses = []
    scores = []

    for batch_idx, (X, y) in enumerate(train_loader):
        # distribute data to device
        X, y = X.to(device), y.to(device)
        X = torch.squeeze(X, 1)  # remove grey-level channel of MNIST

        optimizer.zero_grad()
        output, layer_z_T, layer_qz_T, layer_h_T, _ = model(X, config.tau, is_training=True)
        '''layer_qz_T= qz_T in last layer'''

        y_pred = torch.sigmoid(output).view(-1,)

        # computing entropy loss
        entropy = - layer_qz_T * torch.log(layer_qz_T + 1e-20)
        loss2 = torch.mean(torch.sum(entropy, (1, 2)))

        # define total loss
        if config.obj == 'ER':
            loss = F.binary_cross_entropy(y_pred, y) - config.beta * loss2
        elif config.obj == 'VB':
            loss = F.binary_cross_entropy(y_pred, y) - loss2
        elif config.obj == 'MLE':
            loss = F.binary_cross_entropy(y_pred, y)

        losses.append(loss.item())

        # to compute accuracy
        # y_pred = torch.max(output, 1)[1]  # convert output -> y_pred
        step_score = roc_auc_score(y.cpu().data.squeeze().numpy(), y_pred.cpu().data.squeeze().numpy())
        scores.append(step_score)         # computed on CPU

        loss.backward()

        # # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        torch.nn.utils.clip_grad_norm_(model.parameters(), config.clip)
        for p in model.parameters():
            p.data.add_(-config.lr, p.grad.data)

        optimizer.step()

        # show information
        if batch_idx % config.log_interval == 0:
            print("Learning rate: {:.4f}, Temperature: {:.3f}\n".format(config.lr, config.tau))
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}, AUC: {:.2f}'.format(
                epoch, batch_idx * len(X), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(), step_score))

    return losses, scores


def validation(model, device, test_loader, config):
    model.eval()   # set model in testing mode
    test_loss = 0
    all_y = []
    all_y_pred = []
    with torch.no_grad():
        for X, y in test_loader:
            # distribute data to device
            X, y = X.to(device), y.to(device)
            X = torch.squeeze(X, 1)  # remove grey-level channel for MNIST

            output, layer_z_T, layer_qz_T, layer_h_T, _ = model(X, config.tau, is_training=False)
            '''layer_qz_T: last layer qz_T'''

            y_pred = torch.sigmoid(output).view(-1,)

            # computing entropy loss
            entropy = - layer_qz_T * torch.log(layer_qz_T + 1e-20)
            entropy = entropy.sum(1).sum(1).sum()

            # define total loss
            if config.obj == 'ER':
                loss = F.binary_cross_entropy(y_pred, y) - config.beta * entropy
            elif config.obj == 'VB':
                loss = F.binary_cross_entropy(y_pred, y) - entropy
            elif config.obj == 'MLE':
                loss = F.binary_cross_entropy(y_pred, y)

            test_loss += loss.item()                 # sum up batch loss
            # y_pred = output.max(1, keepdim=True)[1]  # (y_pred != output) get the index of the max log-probability

            # collect all y and y_pred in all batches
            all_y.extend(y)
            all_y_pred.extend(y_pred)

    test_loss /= len(test_loader.dataset)

    # to compute accuracy
    all_y = torch.stack(all_y, dim=0)
    all_y_pred = torch.stack(all_y_pred, dim=0)
    test_score = roc_auc_score(all_y.cpu().data.squeeze().numpy(), all_y_pred.cpu().data.squeeze().numpy())

    # show info
    print('\nTest set ({:d} samples): Average loss: {:.4f}, Accuracy: {:.2f}\n'.format(len(all_y), test_loss, test_score))

    return test_loss, test_score

# %% [markdown]
# ### set training parameters

# %%
class Config(object):
    init_scale = 0.1
    epochs = 10
    batch_size = 150
    display_step = 100
    lr = 1e-3
    clip = 0.25         # gradient clip threshold to avoid grdient explosion
    vocab_size = 10000
    tau0 = 5.0          # initial temperature
    anneal_rate = 0.1
    min_temp = 0.1
    beta = 0.001
    log_interval = 100
    obj = 'ER'          # define MRNN loss objective, select: 'MLE','VB','ER'

    # Network Parameters
    input_size = 1
    hidden_size = 128
    num_class = 1       # binary prediction
    T = 50              # timesteps of data
    num_layers = 1
    K = 4               # LSTM numbers

config = Config()

# output
output_folder = './outputs/'

# %% [markdown]
# ### make artificial dataset (wave signal: 0=no alien, 1=alien)

# %%
N = 50000    # sample number
# generate sin waves
x0 = 2* np.random.rand(N) - 1      # random initial wave phase
x, X, y = np.zeros((N, config.T)), np.zeros((N, config.T, 1)), np.random.randint(2, size=N)

# add high freq signals
high_freq = np.random.choice(np.arange(100, 200), N)
freq_shift = 5 * np.random.rand(N)

for i in range(N):
    x[i, :] = np.linspace(x0[i] * np.pi, x0[i] * np.pi + 20, config.T)
    X[i, :, 0] = np.sin(x[i]) + y[i] * np.cos(high_freq[i] * x[i] + freq_shift[i])

# %%
for i in range(20):
    plt.figure()
    plt.plot(np.arange(0, config.T), X[i])
    plt.xlabel('time step')
    sgn = 'alien' if y[i] == 1 else 'no alien'  # title
    plt.title(sgn)
    plt.show()

# %%
# Data loader
mydataset = data.TensorDataset(torch.from_numpy(X).float(), torch.from_numpy(y).float())

train_loader = data.DataLoader(dataset=mydataset, batch_size=config.batch_size, shuffle=True)
test_loader = data.DataLoader(dataset=mydataset, batch_size=config.batch_size, shuffle=False)

# %% [markdown]
# ### start training

# %%
# check GPU devices
use_cuda = torch.cuda.is_available()                   # check if GPU exists
device = torch.device("cuda" if use_cuda else "cpu")   # use CPU or GPU

# set dataloader parameters
params = {'batch_size': config.batch_size, 'shuffle': True, 'num_workers': 4, 'pin_memory': True} if use_cuda else {}

# create model
mrnn = LSTM(cell_class=LSTMCell, input_size=config.input_size, hidden_size=config.hidden_size,
            output_size=config.num_class, num_layers=config.num_layers, k_cells=config.K, use_bias=True, dropout_prob=0.5).to(device)

optimizer = torch.optim.Adam(mrnn.parameters(), lr=config.lr)   # optimize all cnn parameters

# Training cycle
for epoch in range(config.epochs):
    avg_cost = 0.

    # adjust Gumbel softmax temp
    config.tau = np.maximum(config.tau0 * np.exp(-config.anneal_rate * epoch), config.min_temp)
    # training model
    train_losses, train_scores = train(mrnn, device, train_loader, optimizer, config, epoch)

for epoch in range(1):
    # model validation
    print('-' * 80); print('validating'); print('-' * 80)
    epoch_test_loss, epoch_test_score = validation(mrnn, device, test_loader, config)
# Out:
# LSTM cell parameters reseted!
# Learning rate: 0.0010, Temperature: 5.000
#
# Train Epoch: 0 [0/50000 (0%)]	Loss: 0.625888, AUC: 0.50
# Learning rate: 0.0010, Temperature: 5.000
#
# Train Epoch: 0 [15000/50000 (30%)]	Loss: 0.505866, AUC: 0.94
# Learning rate: 0.0010, Temperature: 5.000
#
# Train Epoch: 0 [30000/50000 (60%)]	Loss: 0.623378, AUC: 0.54
# Learning rate: 0.0010, Temperature: 5.000
#
# Train Epoch: 0 [45000/50000 (90%)]	Loss: 0.624352, AUC: 0.52
# Learning rate: 0.0010, Temperature: 4.524
#
# Train Epoch: 1 [0/50000 (0%)]	Loss: 0.624527, AUC: 0.53
# Learning rate: 0.0010, Temperature: 4.524
#
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 0.624578, AUC: 0.57
# Learning rate: 0.0010, Temperature: 4.524
#
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 0.620787, AUC: 0.65
# Learning rate: 0.0010, Temperature: 4.524
#
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 0.583394, AUC: 0.58
# Learning rate: 0.0010, Temperature: 4.094
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.503155, AUC: 0.85
# Learning rate: 0.0010, Temperature: 4.094
#
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 0.079684, AUC: 0.99
# Learning rate: 0.0010, Temperature: 4.094
#
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 0.014535, AUC: 0.99
# Learning rate: 0.0010, Temperature: 4.094
#
# Train Epoch: 2 [45000/50000 (90%)]	Loss: 0.082723, AUC: 0.98
# Learning rate: 0.0010, Temperature: 3.704
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.006487, AUC: 0.99
# Learning rate: 0.0010, Temperature: 3.704
#
# Train Epoch: 3 [15000/50000 (30%)]	Loss: -0.045321, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.704
#
# Train Epoch: 3 [30000/50000 (60%)]	Loss: -0.027836, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.704
#
# Train Epoch: 3 [45000/50000 (90%)]	Loss: -0.062515, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.352
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: -0.064720, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.352
#
# Train Epoch: 4 [15000/50000 (30%)]	Loss: -0.065813, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.352
#
# Train Epoch: 4 [30000/50000 (60%)]	Loss: -0.045576, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.352
#
# Train Epoch: 4 [45000/50000 (90%)]	Loss: -0.066863, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.033
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: -0.067417, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.033
#
# Train Epoch: 5 [15000/50000 (30%)]	Loss: -0.067656, AUC: 1.00
# Learning rate: 0.0010, Temperature: 3.033
#
# Train Epoch: 5 [30000/50000 (60%)]	Loss: -0.001906, AUC: 0.98
# Learning rate: 0.0010, Temperature: 3.033
#
# Train Epoch: 5 [45000/50000 (90%)]	Loss: -0.068027, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.744
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: -0.068319, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.744
#
# Train Epoch: 6 [15000/50000 (30%)]	Loss: -0.052114, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.744
#
# Train Epoch: 6 [30000/50000 (60%)]	Loss: -0.068752, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.744
#
# Train Epoch: 6 [45000/50000 (90%)]	Loss: -0.068705, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.483
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: -0.068721, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.483
#
# Train Epoch: 7 [15000/50000 (30%)]	Loss: -0.012635, AUC: 0.99
# Learning rate: 0.0010, Temperature: 2.483
#
# Train Epoch: 7 [30000/50000 (60%)]	Loss: 0.436866, AUC: 0.93
# Learning rate: 0.0010, Temperature: 2.483
#
# Train Epoch: 7 [45000/50000 (90%)]	Loss: -0.067278, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.247
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.002158, AUC: 0.99
# Learning rate: 0.0010, Temperature: 2.247
#
# Train Epoch: 8 [15000/50000 (30%)]	Loss: 0.094055, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.247
#
# Train Epoch: 8 [30000/50000 (60%)]	Loss: -0.068523, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.247
#
# Train Epoch: 8 [45000/50000 (90%)]	Loss: -0.068045, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.033
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: -0.068265, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.033
#
# Train Epoch: 9 [15000/50000 (30%)]	Loss: -0.068691, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.033
#
# Train Epoch: 9 [30000/50000 (60%)]	Loss: -0.068512, AUC: 1.00
# Learning rate: 0.0010, Temperature: 2.033
#
# Train Epoch: 9 [45000/50000 (90%)]	Loss: -0.068919, AUC: 1.00
# --------------------------------------------------------------------------------
# validating
# --------------------------------------------------------------------------------
#
# Test set (50000 samples): Average loss: -0.0673, Accuracy: 1.00

# %% [markdown]
# ## Display some images

# %%
total_prob = 0
eval_config = Config()
eval_config.batch_size = 1
eval_config.T = 1
random_pick = 2

# load test samples
X, y = next(iter(test_loader))
X, y = X.to(device), y.to(device)

for i in range(eval_config.num_class + 1):
    # select samples of label y=i
    X_i, y_i = X[y == i, :], y[y == i]

    eval_config.batch_size = X_i.shape[0]
    with torch.no_grad():
        output, layer_z_T, layer_qz_T, layer_h_T, _ = mrnn(X_i, eval_config.tau0, is_training=False)
    
    # compute probability of LSTM usage (integrating) over time and selected samples
    prob = torch.einsum('ijk->k', (layer_z_T,)) / torch.sum(layer_z_T)
    prob = prob.data.cpu().numpy()
    total_prob += prob

    # plot image
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(np.arange(0, config.T), X_i[random_pick, :, 0].data.cpu().numpy())
    plt.xlabel('time')
    sgn = 'alien' if y_i[random_pick].data.cpu().numpy() == 1 else 'no alien'  # title
    plt.title(sgn)

    # plot probability(k LSTM)
    plt.subplot(1, 2, 2)
    plt.bar(np.arange(eval_config.K) + 1, prob, alpha=0.8)
    plt.xlabel('{} LSTMs'.format(eval_config.K))
    plt.ylabel('Probability')

    plt.show()

# plot total probability (over all classes [labels])
total_prob = total_prob / eval_config.num_class
plt.figure(figsize=(5, 5))
plt.bar(np.arange(eval_config.K) + 1, total_prob, alpha=0.8)
plt.xlabel('{} LSTMs'.format(eval_config.K))
plt.ylabel('Total probability (over all timesteps)')
plt.show()

# %% [markdown]
# ## Plot $z(t)$ and $q_z(t)$ , where $t \in [0, T]$

# %%
# plot waves of two catogories

for i in range(eval_config.num_class + 1):
    # select samples of label y=i
    X_i, y_i = X[y == i, :], y[y == i]
    
    eval_config.batch_size = 10
    X_i, y_i = X_i[:eval_config.batch_size], y_i[:eval_config.batch_size]

    with torch.no_grad():
        output, layer_z_T, layer_qz_T, layer_h_T, _ = mrnn(X_i, eval_config.tau0, is_training=False)
    
    # randomly pick few representatives in each class
    for random_pick in range(len(X_i)):
        # plot 1: image (time) series
        plt.figure(figsize=(17, 2))
        plt.plot(np.arange(0, config.T), X_i[random_pick, :, 0].data.cpu().numpy())
        sgn = 'alien' if y_i[random_pick].data.cpu().numpy() == 1 else 'no alien'  # title
        plt.title(sgn)
        plt.xlim(0,50)
        plt.xlabel('t')
        plt.grid()
        plt.savefig(os.path.join(output_folder, 'wave{}_random{}.png'.format(i, random_pick)), dpi=600)
        plt.show()

        # plot 2: soft transition function: q_z(t)
        plt.figure(figsize=(18, 15))
        plt.imshow(layer_qz_T[random_pick].data.cpu().numpy().T)
        plt.xlabel('q_z(t)')
        plt.ylabel('{} LSTMs'.format(eval_config.K))
        plt.grid()
        plt.savefig(os.path.join(output_folder, 'qz_t_wave{}_random{}.png'.format(i, random_pick)), dpi=600)
        plt.show()

        # plot 3: Gumbel sampling of transition function: z(t)
        plt.figure(figsize=(18, 15))
        plt.imshow(layer_z_T[random_pick].data.cpu().numpy().T)
        plt.xlabel('z(t)')
        plt.ylabel('{} LSTMs'.format(eval_config.K))
        plt.grid()
        plt.savefig(os.path.join(output_folder, 'z_t_wave{}_random{}.png'.format(i, random_pick)), dpi=600)
        plt.show()

        print('-' * 80)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
